# %% [markdown]
# # Tugas Besar - IF2220 - Probabilitas dan Statistika
# ***
# ```
# ```
# ## Author
#
# | NIM      | Nama                  |
# |:----------:|:-----------------------:|
# | 13522134 | Shabrina Maharani     |
# | 13522148 | Auralea Alvinia Syaikha |
#
# ***
# ```
# ```
#
# ## Panduan Enam Langkah Testing:
# 1. Tentukan Hipotesis nol $(H_0: θ = θ_0)$, dimana $θ$ bisa berupa $μ$, $σ^2$, $p$, atau data lain berdistribusi tertentu (normal, binomial, dsc.).
# 2. Pilih hipotesis alternatif $H_1$ salah dari dari $θ > θ_0$, $θ < θ_0$, atau $θ ≠ θ_0$.
# 3. Tentukan tingkat signifikan $α$.
# 4. Tentukan uji statistik yang sesuai dan tentukan daerah kritis.
# 5. Hitung nilai uji statistik dari data sample. Hitung $p$-value sesuai dengan uji statistik yang digunakan.
# 6. Ambil keputusan dengan **TOLAK** $H_0$ jika nilai uji terletak di daerah kritis atau dengan tes signifikan, **TOLAK** $H_0$ jika $p$-value lebih kecil dibanding tingkat signifikansi $α$ yang diinginkan

# %% [markdown]
# # Problem Set
# ***
# ```
# ```
# Mira adalah seorang peneliti kesehatan yang bekerja di sebuah lembaga riset medis yang terkemuka. Sebagai bagian dari tugasnya, Mira memiliki akses ke sebuah dataset yang berisi informasi tentang profil kesehatan dan gaya hidup dari sejumlah individu. Mira bertanggung jawab untuk melakukan analisis statistika terhadap dataset ini guna mendapatkan pemahaman yang lebih baik tentang faktor-faktor yang mempengaruhi kesehatan dan kualitas hidup individu. Selain itu, Mira juga diminta untuk mengidentifikasi pola dan hubungan yang signifikan antara variabel-variabel tersebut, serta untuk menjawab berbagai pertanyaan penelitian yang diajukan oleh lembaga riset.
# ***
# ```
# ```
# Diberikan sebuah dataset health.csv yang merupakan data metrik yang menggambarkan informasi tentang profil kesehatan dan gaya hidup dari sejumlah individu. Data tersebut terdiri dari 12 kolom, kolom pertama menggambarkan indeks dari setiap profile dan 11 kolom lainnya merupakan atribut dari dataset health. Atribut-atribut tersebut diantaranya adalah sebagai berikut.
# 1. Age
# 2. Income
# 3. Gender
# 4. Education
# 5. Stress_Level
# 6. Exercise_Hours_Per_Week
# 7. Cholesterol_Level
# 8. Weight
# 9. Height
# 10. Blood_Pressure
# 11. Health_Status
# ***
# ```
# ```
# ### Soal General
# 1. Menulis deskripsi statistika (Descriptive Statistics) dari semua kolom pada data. Data yang bersifat numerik dapat diberikan nilai mean, median, modus, standar deviasi, variansi, range, nilai minimum, maksimum, kuartil, IQR, skewness dan kurtosis. Data dalam bentuk string dapat dicari unique values, dan proporsi nya.
#
# 2. Apakah pada data tersebut terdapat outlier? Jika ya, dapatkah anda menanganinya? Jelaskan apa yang umumnya dilakukan untuk menangani outlier.
#
# 3. Membuat Visualisasi plot distribusi. Berikan uraian penjelasan kondisi setiap kolom berdasarkan kedua plot tersebut. Jika numerik dapat dibuat dalam bentuk histogram dan box plot, dan jika string dengan histogram.
#
# 4. Menentukan distribusi setiap kolom numerik menggunakan hasil visualisasi histogram. Apakah kolom tersebut berdistribusi normal? Jika bukan, terdistribusi seperti apa kolom tersebut?
#
# ### Soal Spesifik
# 5. Hipotesis 1 sampel
# - Lembaga riset saat ini sedang mempertanyakan data berat badan individu yang disimpan untuk kepentingan riset lanjutan. Identifikasilah apakah rata-rata berat badan pasien diatas 65 kg?
# - Tekanan darah sistole yang normal berada pada rentang 120 mmHg. Lembaga riset perlu untuk memastikan apakah data individu yang diukur cukup normal. Periksalah apakah rata-rata tekanan darah sistole bernilai 120 mmHg?
# - Periksalah apakah data 200 individu pertama pengujian (baris teratas) memiliki rata-rata waktu olahraga per minggu tidak sama dengan 15 jam?
# - Apakah penduduk dengan pendapatan yang lebih besar dari Rp 7.500.000,00 tidak sama dengan 30% dari data keseluruhan individu?
#
# 6. Hipotesis 2 sampel
# Lembaga riset membagi data individu menjadi dua bagian, yaitu data individu yang lebih awal masuk data penelitian (bagian atas) dan yang baru saja (bagian bawah).
#
# - Periksa apakah rata-rata berat badan individu yang lebih awal masuk data penelitian sama dengan rata-rata berat badan individu yang masuk baru saja?
# - Bagaimana dengan pendapatan individu, apakah pendapatan sistole individu yang lebih awal masuk data penelitian lebih besar Rp 1.250.000,00 dari yang baru saja masuk?
# - Lembaga riset ingin membandingkan kondisi kesehatan individu dari dua bagian data. Apakah variansi tekanan darah individu yang lebih awal masuk data penelitian sama dengan yang baru saja masuk?
# - Apakah proporsi waktu olahraga yang lebih dari 8 jam per minggu pada data individu awal lebih besar daripada kuantitas proporsi pada data individu akhir dengan waktu olahraga yang sama?
#
#
# Dalam problem set ini, level signifikan yang digunakan adalah $α  = 0.05$

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm, t, f, normaltest
import scipy.stats as stats
import numpy as np
import seaborn as sns
from IPython.display import display, Markdown 
data = pd.read_csv('health.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 from scipy.stats import norm, t, f, normaltest
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # Penyelesaian
# ***
# ```
# ```

# %% [markdown]
# ## 1. Deskripsi Statistika
# ***
# ```
# ```
# ### 1.1. Data Numerik
# Data yang bersifat numerik dapat diberikan nilai mean, median, modus, standar deviasi, variansi, range, nilai minimum, maksimum, kuartil, IQR, skewness dan kurtosis.

# %%
#sorting kolom numerik
datanum = data.iloc[:, 1:].select_dtypes(include=[np.number]) 

# count, mean, std, min, quartile 1(25%), quartile 2(50%), quartile 3(75%), max 
descnum_statistic = datanum.describe()

# median
descnum_statistic.loc['median'] = datanum.median()

# modus
descnum_statistic.loc['modus'] = datanum.mode().iloc[0] 

# variansi
descnum_statistic.loc['variansi'] = datanum.var()

# range
descnum_statistic.loc['range'] = datanum.max() - datanum.min()

# skewness
descnum_statistic.loc['skewness'] = datanum.skew()

# kurtosis
descnum_statistic.loc['kurtosis'] = datanum.kurt()

# Display
descnum_statistic
# Out:
#                   Age        Income  Stress_Level  Exercise_Hours_Per_Week  \
# count     2000.000000  2.000000e+03   2000.000000              2000.000000
# mean        39.417500  4.889928e+06      5.356912                 9.951842
# std         11.560753  2.010795e+06      0.917069                 4.909573
# min         20.000000 -1.088987e+06      2.528057                -4.499310
# 25%         30.000000  3.580714e+06      4.737650                 6.654951
# 50%         39.000000  4.898901e+06      5.351795                 9.927028
# 75%         49.250000  6.271595e+06      6.003014                13.232218
# max         59.000000  1.222749e+07      8.581327                26.816358
# median      39.000000  4.898901e+06      5.351795                 9.927028
# modus       53.000000 -1.088987e+06      2.528057                -4.499310
# variansi   133.651019  4.043297e+12      0.841016                24.103911
# ...

# %% [markdown]
# ***
# ```
# ```
# ### 1.2 Data String
# Data dalam bentuk string dapat dicari unique values, dan proporsi nya.

# %%
# unique value
gender_unique = data['Gender'].value_counts().fillna(0)
education_unique = data['Education'].value_counts().fillna(0)
healths_unique = data['Health_Status'].value_counts().fillna(0)

print(gender_unique)
print()
print(education_unique)
print()
print(healths_unique)
print()

# proporsi
total_rows = len(data)

gender_proportions = gender_unique / total_rows
education_proportions = education_unique / total_rows
healths_proportions = healths_unique / total_rows

print(gender_proportions)
print()
print(education_proportions)
print()
print(healths_proportions)
print()
# Out:
# Gender
# Female    1011
# Male       989
# Name: count, dtype: int64
#
# Education
# Bachelor's Degree    940
# Master's Degree      482
# High School          271
# PhD                  247
# Other                 57
# undefined              3
# Name: count, dtype: int64
#
# Health_Status
# Fair         519
# Poor         504
# Excellent    503
# Good         474
# Name: count, dtype: int64
#
# Gender
# Female    0.5055
# Male      0.4945
# Name: count, dtype: float64
#
# Education
# Bachelor's Degree    0.4700
# Master's Degree      0.2410
# High School          0.1355
# PhD                  0.1235
# Other                0.0285
# undefined            0.0015
# Name: count, dtype: float64
#
# Health_Status
# Fair         0.2595
# Poor         0.2520
# Excellent    0.2515
# Good         0.2370
# Name: count, dtype: float64

# %% [markdown]
# # 2. Outlier
# ***
# ```
# ```

# %% [markdown]
# ## 2.1 Age Column

# %%
fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Age)
plt.title('Box Plot: Age', fontsize=15)
plt.show()

#tidak ada outlier

# %% [markdown]
# ## 2.2 Income Column

# %%
fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Income)
plt.title('Box Plot: Income', fontsize=15)
plt.show()

IQR = datanum.Income.quantile(0.75) - datanum.Income.quantile(0.25)
upper_limit = datanum.Income.quantile(0.75) + 1.5 * IQR
lower_limit = datanum.Income.quantile(0.25) - 1.5 * IQR

# outlier
display(data[~((data.Income < upper_limit) & (data.Income > lower_limit))])

# penanganan
percentile_5 = data.Income.quantile(0.05)
percentile_95 = data.Income.quantile(0.95)

# Winsorization 90%
data['Income_winsorized'] = data['Income'].clip(percentile_5, percentile_95)

fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Income_winsorized)
plt.title('Box Plot: Income (Winsorized)', fontsize=15)
plt.show()
# Out:
#       Unnamed: 0  Age        Income  Gender          Education  Stress_Level  \
# 102          102   20 -5.235745e+05  Female        High School      4.754107
# 453          453   27 -6.372663e+05  Female                PhD      5.297767
# 514          514   46 -4.944103e+05  Female  Bachelor's Degree      5.856028
# 579          579   47  1.044300e+07    Male  Bachelor's Degree      4.113114
# 673          673   33  1.060307e+07  Female    Master's Degree      5.853346
# 835          835   51 -4.719274e+05  Female        High School      3.240034
# 892          892   28 -9.677291e+05  Female  Bachelor's Degree      6.073755
# 1328        1328   59  1.222749e+07  Female  Bachelor's Degree      4.380313
# 1460        1460   29  1.036827e+07  Female        High School      5.310925
# 1686        1686   30  1.198891e+07    Male  Bachelor's Degree      6.785509
# 1697        1697   49 -1.088987e+06    Male  Bachelor's Degree      4.766948
# ...

# %% [markdown]
# ## 2.3 Stress Level Column

# %%
fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Stress_Level)
plt.title('Box Plot: Stress Level', fontsize=15)
plt.show()

IQR2 = datanum.Stress_Level.quantile(0.75) - datanum.Stress_Level.quantile(0.25)
upper_limit2 = datanum.Stress_Level.quantile(0.75) + 1.5 * IQR2
lower_limit2 = datanum.Stress_Level.quantile(0.25) - 1.5 * IQR2

# outlier
display(data[~((data.Stress_Level < upper_limit2) & (data.Stress_Level > lower_limit2))])

# penanganan
percentile_5 = data.Stress_Level.quantile(0.05)
percentile_95 = data.Stress_Level.quantile(0.95)

# Winsorization 90%
data['Stress_Level_winsorized'] = data['Stress_Level'].clip(percentile_5, percentile_95)

fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Stress_Level_winsorized)
plt.title('Box Plot: Stress_Level (Winsorized)', fontsize=15)
plt.show()
# Out:
#       Unnamed: 0  Age        Income  Gender          Education  Stress_Level  \
# 13            13   51  5.314803e+06  Female  Bachelor's Degree      2.528057
# 170          170   35  6.701356e+06    Male  Bachelor's Degree      8.191571
# 201          201   53  5.521208e+06    Male    Master's Degree      7.908383
# 240          240   29  6.239463e+06  Female  Bachelor's Degree      2.661764
# 306          306   43  7.696256e+06  Female  Bachelor's Degree      7.916607
# 393          393   46  5.247321e+06    Male  Bachelor's Degree      7.927514
# 1089        1089   58  4.569280e+06  Female  Bachelor's Degree      2.782488
# 1196        1196   35  2.524041e+06  Female    Master's Degree      8.168885
# 1210        1210   34  5.525325e+06    Male  Bachelor's Degree      2.728318
# 1433        1433   37  2.882209e+06  Female  Bachelor's Degree      8.581327
# 1519        1519   31  6.181065e+06  Female              Other      2.745202
# ...

# %% [markdown]
# ## 2.4 Exercise Hours Per Week Column

# %%
fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Exercise_Hours_Per_Week)
plt.title('Box Plot: Exercise Hours Per Week', fontsize=15)
plt.show()

IQR3 = datanum.Exercise_Hours_Per_Week.quantile(0.75) - datanum.Exercise_Hours_Per_Week.quantile(0.25)
upper_limit3 = datanum.Exercise_Hours_Per_Week.quantile(0.75) + 1.5 * IQR3
lower_limit3 = datanum.Exercise_Hours_Per_Week.quantile(0.25) - 1.5 * IQR3

# outlier
display(data[~((data.Exercise_Hours_Per_Week < upper_limit3) & (data.Exercise_Hours_Per_Week > lower_limit3))])

# penanganan
percentile_5 = data.Exercise_Hours_Per_Week.quantile(0.05)
percentile_95 = data.Exercise_Hours_Per_Week.quantile(0.95)

# Winsorization 90%
data['Exercise_Hours_Per_Week_winsorized'] = data['Exercise_Hours_Per_Week'].clip(percentile_5, percentile_95)

fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Exercise_Hours_Per_Week_winsorized)
plt.title('Box Plot: Exercise Hours Per Week (Winsorized)', fontsize=15)
plt.show()
# Out:
#       Unnamed: 0  Age        Income  Gender          Education  Stress_Level  \
# 48            48   30  7.556343e+06  Female  Bachelor's Degree      4.987827
# 180          180   28  5.061272e+06  Female  Bachelor's Degree      5.472819
# 278          278   41  4.820237e+06    Male  Bachelor's Degree      5.483402
# 330          330   46  3.951613e+06  Female  Bachelor's Degree      6.495517
# 452          452   28  3.309875e+05  Female  Bachelor's Degree      5.944793
# 479          479   53  7.186463e+06    Male  Bachelor's Degree      7.012096
# 580          580   36  5.149823e+06  Female  Bachelor's Degree      3.468253
# 644          644   51  7.292036e+06    Male    Master's Degree      6.486200
# 893          893   29  8.682902e+06    Male  Bachelor's Degree      5.212536
# 1056        1056   55  5.175884e+06  Female        High School      4.619431
# 1147        1147   28  6.858084e+06  Female  Bachelor's Degree      5.780232
# ...

# %% [markdown]
# ## 2.5 Cholestrol_Level

# %%
fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Cholesterol_Level)
plt.title('Box Plot: Cholesterol Level', fontsize=15)
plt.show()

IQR4 = datanum.Cholesterol_Level.quantile(0.75) - datanum.Cholesterol_Level.quantile(0.25)
upper_limit4 = datanum.Cholesterol_Level.quantile(0.75) + 1.5 * IQR4
# print(upper_limit4)
lower_limit4 = datanum.Cholesterol_Level.quantile(0.25) - 1.5 * IQR4
# print(lower_limit4)

# outlier
display(data[~((data.Cholesterol_Level < upper_limit4) & (data.Cholesterol_Level > lower_limit4))])

# penanganan
percentile_5 = data.Cholesterol_Level.quantile(0.05)
percentile_95 = data.Cholesterol_Level.quantile(0.95)

# Winsorization 90%
data['Cholesterol_Level_winsorized'] = data['Cholesterol_Level'].clip(percentile_5, percentile_95)

fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Cholesterol_Level_winsorized)
plt.title('Box Plot: Cholesterol Level (Winsorized)', fontsize=15)
plt.show()
# Out:
#       Unnamed: 0  Age        Income  Gender          Education  Stress_Level  \
# 34            34   20  8.069469e+05  Female  Bachelor's Degree      6.963362
# 98            98   23  6.926901e+06  Female  Bachelor's Degree      4.726457
# 123          123   35  5.768216e+06    Male  Bachelor's Degree      5.432011
# 178          178   35  4.274442e+06  Female  Bachelor's Degree      4.211859
# 358          358   23  5.819435e+06  Female        High School      5.888616
# 723          723   48  7.743874e+06  Female  Bachelor's Degree      5.443509
# 768          768   30  5.922345e+06  Female    Master's Degree      5.295955
# 781          781   56  7.048290e+06  Female  Bachelor's Degree      6.006363
# 840          840   34  1.040724e+06    Male  Bachelor's Degree      4.735199
# 898          898   20  3.709589e+06    Male        High School      5.915512
# 1085        1085   54  2.983307e+06  Female    Master's Degree      4.444645
# ...

# %% [markdown]
# ## 2.6 Weight

# %%
fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Weight)
plt.title('Box Plot: Weight', fontsize=15)
plt.show()

IQR5 = datanum.Weight.quantile(0.75) - datanum.Weight.quantile(0.25)
upper_limit5 = datanum.Weight.quantile(0.75) + 1.5 * IQR5
# print(upper_limit5)
lower_limit5 = datanum.Weight.quantile(0.25) - 1.5 * IQR5
# print(lower_limit5)

# outlier
display(data[~((data.Weight < upper_limit5) & (data.Weight > lower_limit5))])

# penanganan
percentile_5 = data.Weight.quantile(0.05)
percentile_95 = data.Weight.quantile(0.95)

# Winsorization 90%
data['Weight_winsorized'] = data['Weight'].clip(percentile_5, percentile_95)

fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Cholesterol_Level_winsorized)
plt.title('Box Plot: Weight (Winsorized)', fontsize=15)
plt.show()
# Out:
#       Unnamed: 0  Age        Income  Gender          Education  Stress_Level  \
# 236          236   35  4.797096e+06    Male  Bachelor's Degree      3.850187
# 305          305   57  3.396948e+06  Female  Bachelor's Degree      3.816152
# 397          397   44  4.984269e+06  Female  Bachelor's Degree      6.101010
# 506          506   46  4.958995e+06    Male  Bachelor's Degree      5.563736
# 711          711   26  2.850808e+06  Female  Bachelor's Degree      5.278269
# 747          747   36  5.975767e+06  Female    Master's Degree      5.594650
# 779          779   56  5.624153e+06    Male                PhD      6.272742
# 818          818   48  1.975218e+06    Male  Bachelor's Degree      3.684621
# 887          887   42  2.343817e+06  Female                PhD      6.568759
# 986          986   22  6.845451e+05  Female  Bachelor's Degree      6.630392
# 1036        1036   53  4.043785e+06    Male  Bachelor's Degree      4.283279
# ...

# %% [markdown]
# ## 2.7 Height

# %%
fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Height)
plt.title('Box Plot: Height', fontsize=15)
plt.show()

IQR6 = datanum.Height.quantile(0.75) - datanum.Height.quantile(0.25)
upper_limit6 = datanum.Height.quantile(0.75) + 1.5 * IQR6
# print(upper_limit6)
lower_limit6 = datanum.Height.quantile(0.25) - 1.5 * IQR6
# print(lower_limit6)

# outlier
display(data[~((data.Height < upper_limit6) & (data.Height > lower_limit6))])

# penanganan
percentile_5 = data.Height.quantile(0.05)
percentile_95 = data.Height.quantile(0.95)

# Winsorization 90%
data['Height_winsorized'] = data['Height'].clip(percentile_5, percentile_95)

fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Cholesterol_Level_winsorized)
plt.title('Box Plot: Height (Winsorized)', fontsize=15)
plt.show()
# Out:
#       Unnamed: 0  Age        Income  Gender          Education  Stress_Level  \
# 111          111   42  3.232947e+06    Male    Master's Degree      7.149617
# 146          146   40  5.076991e+06    Male  Bachelor's Degree      5.337008
# 277          277   21  3.909727e+06  Female  Bachelor's Degree      4.561763
# 572          572   38  4.085597e+06    Male    Master's Degree      5.069545
# 599          599   49  6.549190e+06  Female  Bachelor's Degree      6.163918
# 610          610   39  3.940286e+06    Male  Bachelor's Degree      6.382846
# 680          680   35  5.843696e+06    Male  Bachelor's Degree      5.083441
# 747          747   36  5.975767e+06  Female    Master's Degree      5.594650
# 762          762   21  4.008222e+06    Male  Bachelor's Degree      7.237600
# 815          815   47  3.065019e+06    Male  Bachelor's Degree      5.816920
# 866          866   20  5.163235e+06  Female    Master's Degree      5.951874
# ...

# %% [markdown]
# ## 2.8 Blood_Pressure

# %%
fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Blood_Pressure)
plt.title('Box Plot: Blood Pressure', fontsize=15)
plt.show()

IQR7 = datanum.Blood_Pressure.quantile(0.75) - datanum.Blood_Pressure.quantile(0.25)
upper_limit7 = datanum.Blood_Pressure.quantile(0.75) + 1.5 * IQR7
print(upper_limit7)
lower_limit7 = datanum.Blood_Pressure.quantile(0.25) - 1.5 * IQR7
print(lower_limit7)

# outlier
display(data[~((data.Blood_Pressure < upper_limit7) & (data.Blood_Pressure > lower_limit7))])

# penanganan
percentile_5 = data.Blood_Pressure.quantile(0.05)
percentile_95 = data.Blood_Pressure.quantile(0.95)

# Winsorization 90%
data['Blood_Pressure_winsorized'] = data['Blood_Pressure'].clip(percentile_5, percentile_95)

fig = plt.figure(figsize=(10,5))
sns.boxplot(data.Blood_Pressure_winsorized)
plt.title('Box Plot: Blood Pressure (Winsorized)', fontsize=15)
plt.show()
# Out:
# 146.949050263135
# 92.70833262948724
#       Unnamed: 0  Age        Income  Gender          Education  Stress_Level  \
# 43            43   31  6.984607e+06    Male    Master's Degree      4.125009
# 117          117   54  8.029925e+06  Female    Master's Degree      5.435872
# 192          192   53  8.472197e+06    Male    Master's Degree      4.854854
# 230          230   33  5.718684e+06    Male    Master's Degree      5.116797
# 249          249   35  4.354482e+06  Female    Master's Degree      7.286905
# 316          316   57  8.012844e+06  Female  Bachelor's Degree      4.171713
# 323          323   27  2.626085e+06  Female                PhD      4.608875
# 417          417   54  5.423861e+06  Female  Bachelor's Degree      4.820469
# 526          526   23  1.139604e+06  Female        High School      6.349844
# 617          617   55  4.315456e+06  Female              Other      5.337303
# 715          715   43  2.701903e+06    Male    Master's Degree      5.060992
# ...

# %% [markdown]
# # 3 & 4. Visualisasi Plot Distribusi & Analisis Kolom

# %%
# drop kolom data yang belum di handling outlier nya
data = data.drop(columns=['Income'])
data = data.drop(columns=['Stress_Level'])
data = data.drop(columns=['Exercise_Hours_Per_Week'])
data = data.drop(columns=['Cholesterol_Level'])
data = data.drop(columns=['Weight'])
data = data.drop(columns=['Height'])
data = data.drop(columns=['Blood_Pressure'])
display(data)

# renaming
data = data.rename(columns={'Income_winsorized': 'Income'})
data = data.rename(columns={'Stress_Level_winsorized': 'Stress_Level'})
data = data.rename(columns={'Exercise_Hours_Per_Week_winsorized': 'Exercise_Hours_Per_Week'})
data = data.rename(columns={'Cholesterol_Level_winsorized': 'Cholesterol_Level'})
data = data.rename(columns={'Weight_winsorized': 'Weight'})
data = data.rename(columns={'Height_winsorized': 'Height'})
data = data.rename(columns={'Blood_Pressure_winsorized': 'Blood_Pressure'})
display(data)
# Out:
#       Unnamed: 0  Age  Gender          Education Health_Status  \
# 0              0   50    Male  Bachelor's Degree     Excellent
# 1              1   44    Male  Bachelor's Degree          Fair
# 2              2   25    Male    Master's Degree     Excellent
# 3              3   41  Female        High School          Poor
# 4              4   24    Male  Bachelor's Degree          Fair
# ...          ...  ...     ...                ...           ...
# 1995        1995   22    Male    Master's Degree          Fair
# 1996        1996   25  Female    Master's Degree     Excellent
# 1997        1997   44    Male                PhD          Poor
# 1998        1998   20    Male  Bachelor's Degree          Good
# 1999        1999   51    Male  Bachelor's Degree          Poor
#
#       Income_winsorized  Stress_Level_winsorized  \
# 0          3.093457e+06                 4.967887
# 1          5.545445e+06                 5.833649
# 2          4.401808e+06                 5.587946
# ...

# %% [markdown]
# ## 3.1 Age

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

# Boxplot
sns.boxplot(data=data, x='Age', ax=axes[0])
axes[0].set_title('Box Plot: Age')

# Histogram
sns.histplot(data=data, x='Age', kde=True, ax=axes[1])
axes[1].set_title('Histogram: Age')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dari histogram diatas, terlihat bahwa distribusi data Age tidak memiliki simetri karena terdapat beberapa puncak. Dari boxplot, terlihat juga bahwa garis median (Q2) berada di sekitar nilai 35-40 tahun, dimana median tidak berada tepat di tengah rentang antara kuartil ketiga dan kuartil pertama (IQR), keberadaan outlier pun tidak cukup terlihat. Oleh karena itu, dapat disimpulkan bahwa distribusi data cenderung **tidak normal**.

# %% [markdown]
# ## 3.2 Income

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

# Boxplot
sns.boxplot(data=data, x='Income', ax=axes[0])
axes[0].set_title('Box Plot: Income')

# Histogram
sns.histplot(data=data, x='Income', kde=True, ax=axes[1])
axes[1].set_title('Histogram: Income')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dari histogram diatas, terlihat bahwa distribusi data Income memiliki puncak yang relatif simetris, dan pada boxplot, median (Q2) berada di tengah rentang antara kuartil ketiga dan kuartil pertama (IQR). Dari sini, dapat disimpulkan bahwa distribusi data cenderung **normal**.

# %% [markdown]
# ## 3.3 Gender

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='Gender')
plt.title('Histogram: Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Dari histogram diatas, terlihat bahwa distribusi data Gender tidak simetris terhadap garis rata-rata. Kurva lebih banyak terkonsentrasi di sebelah kanan (jenis kelamin perempuan) dan lebih sedikit di sebelah kiri (jenis kelamin laki-laki). Hal ini menunjukkan bahwa data terdistribusi miring ke kanan (right-skewed). Oleh karena itu, distribusi data diatas dapat dikatakan cenderung **tidak normal**.

# %% [markdown]
# ## 3.4 Education

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Education')
plt.title('Histogram: Education')
plt.xlabel('Education')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Dari histogram diatas, terlihat bahwa distribusi data Education tidak simetris terhadap garis rata-rata. Kurva lebih banyak terkonsentrasi di sebelah kiri dan lebih sedikit di sebelah kanan. Hal ini menunjukkan bahwa data terdistribusi miring ke kiri (left-skewed). Oleh karena itu, distribusi data diatas dapat dikatakan cenderung **tidak normal**.

# %% [markdown]
# ## 3.5 Stress Level

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

# Boxplot
sns.boxplot(data=data, x='Stress_Level', ax=axes[0])
axes[0].set_title('Box Plot: Stress_Level')

# Histogram
sns.histplot(data=data, x='Stress_Level', kde=True, ax=axes[1])
axes[1].set_title('Histogram: Stress_Level')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dari histogram diatas, terlihat bahwa distribusi data Income memiliki puncak yang relatif simetris, dan pada boxplot, median (Q2) berada di tengah rentang antara kuartil ketiga dan kuartil pertama (IQR). Dari sini, dapat disimpulkan bahwa distribusi data cenderung **normal**.

# %% [markdown]
# ## 3.6 Exercise Hours Per Week

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

# Boxplot
sns.boxplot(data=data, x='Exercise_Hours_Per_Week', ax=axes[0])
axes[0].set_title('Box Plot: Exercise_Hours_Per_Week')

# Histogram
sns.histplot(data=data, x='Exercise_Hours_Per_Week', kde=True, ax=axes[1])
axes[1].set_title('Histogram: Exercise_Hours_Per_Week')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
#       4 fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ## 3.7 Cholestrol Level

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

# Boxplot
sns.boxplot(data=data, x='Cholesterol_Level', ax=axes[0])
axes[0].set_title('Box Plot: Cholesterol_Level')

# Histogram
sns.histplot(data=data, x='Cholesterol_Level', kde=True, ax=axes[1])
axes[1].set_title('Histogram: Cholesterol_Level')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dari histogram diatas, terlihat bahwa distribusi data Cholesterol Level memiliki puncak yang relatif simetris, dan pada boxplot, median (Q2) berada di tengah rentang antara kuartil ketiga dan kuartil pertama (IQR). Dari sini, dapat disimpulkan bahwa distribusi data cenderung **normal**.

# %% [markdown]
# ## 3.8 Weight

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

# Boxplot
sns.boxplot(data=data, x='Weight', ax=axes[0])
axes[0].set_title('Box Plot: Weight')

# Histogram
sns.histplot(data=data, x='Weight', kde=True, ax=axes[1])
axes[1].set_title('Histogram: Weight')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dari histogram diatas, terlihat bahwa distribusi data Weight memiliki puncak yang relatif simetris, dan pada boxplot, median (Q2) berada di tengah rentang antara kuartil ketiga dan kuartil pertama (IQR). Dari sini, dapat disimpulkan bahwa distribusi data cenderung **normal**.

# %% [markdown]
# ## 3.9 Height

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

# Boxplot
sns.boxplot(data=data, x='Height', ax=axes[0])
axes[0].set_title('Box Plot: Height')

# Histogram
sns.histplot(data=data, x='Height', kde=True, ax=axes[1])
axes[1].set_title('Histogram: Height')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dari histogram diatas, terlihat bahwa distribusi data Height tidak simetris terhadap garis rata-rata. Kurva lebih banyak terkonsentrasi di sebelah kiri dan lebih sedikit di sebelah kanan. Hal ini menunjukkan bahwa data terdistribusi miring ke kiri (left-skewed). Oleh karena itu, distribusi data diatas dapat dikatakan cenderung **tidak normal**.

# %% [markdown]
# ## 3.10 Blood_Pressure

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

# Boxplot
sns.boxplot(data=data, x='Blood_Pressure', ax=axes[0])
axes[0].set_title('Box Plot: Blood_Pressure')

# Histogram
sns.histplot(data=data, x='Blood_Pressure', kde=True, ax=axes[1])
axes[1].set_title('Histogram: Blood_Pressure')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dari histogram diatas, terlihat bahwa distribusi data Blood_Pressure memiliki puncak yang relatif simetris, dan pada boxplot, median (Q2) berada di tengah rentang antara kuartil ketiga dan kuartil pertama (IQR). Dari sini, dapat disimpulkan bahwa distribusi data cenderung **normal**.

# %% [markdown]
# ## 3.11 Health Status

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Health_Status')
plt.title('Histogram: Health_Status')
plt.xlabel('Health_Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Dari histogram diatas, terlihat bahwa distribusi data Gender tidak simetris terhadap garis rata-rata. Kurva lebih banyak terkonsentrasi di sebelah kiri (fair) dan lebih sedikit di sebelah kanan. Hal ini menunjukkan bahwa data terdistribusi miring ke kiri (left-skewed). Oleh karena itu, distribusi data diatas dapat dikatakan cenderung **tidak normal**.
